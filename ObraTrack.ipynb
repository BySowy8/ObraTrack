# %% [markdown]
# <a href="https://colab.research.google.com/github/BySowy8/ObraTrack/blob/Rama-Angel/ObraTrack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install supabase
# Out:
# Collecting supabase
#   Downloading supabase-2.31.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting realtime==2.31.0 (from supabase)
#   Downloading realtime-2.31.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting supabase-functions==2.31.0 (from supabase)
#   Downloading supabase_functions-2.31.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting storage3==2.31.0 (from supabase)
#   Downloading storage3-2.31.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting supabase-auth==2.31.0 (from supabase)
#   Downloading supabase_auth-2.31.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting postgrest==2.31.0 (from supabase)
#   Downloading postgrest-2.31.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: httpx<0.29,>=0.26 in /usr/local/lib/python3.13/dist-packages (from supabase) (0.28.1)
# Requirement already satisfied: yarl>=1.22.0 in /usr/local/lib/python3.13/dist-packages (from supabase) (1.24.5)
# Requirement already satisfied: deprecation>=2.1.0 in /usr/local/lib/python3.13/dist-packages (from postgrest==2.31.0->supabase) (2.1.0)
# Requirement already satisfied: pydantic<3.0,>=1.9 in /usr/local/lib/python3.13/dist-packages (from postgrest==2.31.0->supabase) (2.13.4)
# Requirement already satisfied: typing-extensions>=4.14.0 in /usr/local/lib/python3.13/dist-packages (from realtime==2.31.0->supabase) (4.16.0)
# Requirement already satisfied: websockets<16,>=11 in /usr/local/lib/python3.13/dist-packages (from realtime==2.31.0->supabase) (15.0.1)
# Requirement already satisfied: pyjwt>=2.12.0 in /usr/local/lib/python3.13/dist-packages (from pyjwt[crypto]>=2.12.0->supabase-auth==2.31.0->supabase) (2.13.0)
# Collecting strenum>=0.4.15 (from supabase-functions==2.31.0->supabase)
#   Downloading StrEnum-0.4.15-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx<0.29,>=0.26->supabase) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<0.29,>=0.26->supabase) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<0.29,>=0.26->supabase) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.13/dist-packages (from httpx<0.29,>=0.26->supabase) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<0.29,>=0.26->supabase) (0.16.0)
# Requirement already satisfied: multidict>=4.0 in /usr/local/lib/python3.13/dist-packages (from yarl>=1.22.0->supabase) (6.7.1)
# Requirement already satisfied: propcache>=0.2.1 in /usr/local/lib/python3.13/dist-packages (from yarl>=1.22.0->supabase) (0.5.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from deprecation>=2.1.0->postgrest==2.31.0->supabase) (26.3)
# Requirement already satisfied: h2<5,>=3 in /usr/local/lib/python3.13/dist-packages (from httpx[http2]<0.29,>=0.26->postgrest==2.31.0->supabase) (4.4.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0,>=1.9->postgrest==2.31.0->supabase) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0,>=1.9->postgrest==2.31.0->supabase) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0,>=1.9->postgrest==2.31.0->supabase) (0.4.4)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.13/dist-packages (from pyjwt[crypto]>=2.12.0->supabase-auth==2.31.0->supabase) (50.0.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.12.0->supabase-auth==2.31.0->supabase) (2.1.1)
# Requirement already satisfied: hyperframe<7,>=6.1 in /usr/local/lib/python3.13/dist-packages (from h2<5,>=3->httpx[http2]<0.29,>=0.26->postgrest==2.31.0->supabase) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.2 in /usr/local/lib/python3.13/dist-packages (from h2<5,>=3->httpx[http2]<0.29,>=0.26->postgrest==2.31.0->supabase) (4.2.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.12.0->supabase-auth==2.31.0->supabase) (3.0)
# Downloading supabase-2.31.0-py3-none-any.whl (16 kB)
# Downloading postgrest-2.31.0-py3-none-any.whl (23 kB)
# Downloading realtime-2.31.0-py3-none-any.whl (22 kB)
# Downloading storage3-2.31.0-py3-none-any.whl (28 kB)
# Downloading supabase_auth-2.31.0-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 2.4 MB/s eta 0:00:00
# Downloading supabase_functions-2.31.0-py3-none-any.whl (8.8 kB)
# Downloading StrEnum-0.4.15-py3-none-any.whl (8.9 kB)
# Installing collected packages: strenum, realtime, supabase-functions, supabase-auth, storage3, postgrest, supabase
# Successfully installed postgrest-2.31.0 realtime-2.31.0 storage3-2.31.0 strenum-0.4.15 supabase-2.31.0 supabase-auth-2.31.0 supabase-functions-2.31.0

# %%
# !find / -iname "*obratrack-hu2*" 2>/dev/null

# %%
# !unzip -o /content/obratrack-hu2.zip -d /content/temp_hu2
# Out:
# unzip:  cannot find or open /content/obratrack-hu2.zip, /content/obratrack-hu2.zip.zip or /content/obratrack-hu2.zip.ZIP.

# %%
# !ls /content/temp_hu2
# Out:
# ls: cannot access '/content/temp_hu2': No such file or directory

# %%
from supabase import create_client

url = "https://syosgdsranzmrajczgrd.supabase.co/rest/v1/"       # tu Project URL
key = "sb_publishable_P-zjN2qYgSN5Q6joPb36eA_AZR9W1Hw"                           # tu anon public key

supabase = create_client(url, key)

# %%
# !ls /content
# Out:
# sample_data

# %%
# !unzip
# Out:
# UnZip 6.00 of 20 April 2009, by Debian. Original by Info-ZIP.
#
# Usage: unzip [-Z] [-opts[modifiers]] file[.zip] [list] [-x xlist] [-d exdir]
#   Default action is to extract files in list, except those in xlist, to exdir;
#   file[.zip] may be a wildcard.  -Z => ZipInfo mode ("unzip -Z" for usage).
#
#   -p  extract files to pipe, no messages     -l  list files (short format)
#   -f  freshen existing files, create none    -t  test compressed archive data
#   -u  update files, create if necessary      -z  display archive comment only
#   -v  list verbosely/show version info       -T  timestamp archive to latest
#   -x  exclude files that follow (in xlist)   -d  extract files into exdir
# modifiers:
#   -n  never overwrite existing files         -q  quiet mode (-qq => quieter)
#   -o  overwrite files WITHOUT prompting      -a  auto-convert any text files
#   -j  junk paths (do not make directories)   -aa treat ALL files as text
#   -U  use escapes for all non-ASCII Unicode  -UU ignore any Unicode fields
#   -C  match filenames case-insensitively     -L  make (some) names lowercase
#   -X  restore UID/GID info                   -V  retain VMS version numbers
#   -K  keep setuid/setgid/tacky permissions   -M  pipe through "more" pager
#   -O CHARSET  specify a character encoding for DOS, Windows and OS/2 archives
#   -I CHARSET  specify a character encoding for UNIX and other archives
#
# See "unzip -hh" or unzip.txt for more help.  Examples:
#   unzip data1 -x joe   => extract all files except joe from zipfile data1.zip
#   unzip -p foo | more  => send contents of foo.zip via pipe into program more
#   unzip -fo foo ReadMe => quietly replace existing ReadMe if archive file newer

# %%
# %cd /content/ObraTrack

# !rm -rf ObraTrack


# !rm -f schema.sql env.example download


# !printf ".env\n__pycache__/\n*.pyc\n.ipynb_checkpoints/\n.venv/\n" > .gitignore


# !find /content/ObraTrack -type f -not -path "*/.git/*" | sort
# Out:
# [Errno 2] No such file or directory: '/content/ObraTrack'
# /content
# find: ‘/content/ObraTrack’: No such file or directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Sube todos los archivos creados al repositorio
# !git add .
# !git config user.name "TuNombreEnGitHub"
# !git config user.email "tu_correo@ejemplo.com"
# !git commit -m "Estructura completa de HU2 e imprevistos lista"
# !git push origin Rama-Jean
# Out:
# [Rama-Jean 6daea53] Estructura completa de HU2 e imprevistos lista
#  12 files changed, 812 insertions(+), 2 deletions(-)
#  create mode 100644 .env.example
#  create mode 100644 .gitignore
#  create mode 100644 ObraTrack_HU2_Colab.ipynb
#  rewrite README.md (100%)
#  create mode 100644 main.py
#  create mode 100644 models.py
#  create mode 100644 requirements.txt
#  create mode 100644 routers/__init__.py
#  create mode 100644 routers/imprevistos.py
#  create mode 100644 sql/schema.sql
#  create mode 100644 supabase_client.py
#  create mode 100644 tests/prueba_manual.py
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git clone https://github.com/BySowy8/ObraTrack.git
# Out:
# Cloning into 'ObraTrack'...
# remote: Enumerating objects: 36, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 36 (delta 13), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (36/36), 10.15 KiB | 10.15 MiB/s, done.
# Resolving deltas: 100% (13/13), done.

# %%
# %cd ObraTrack
# !git checkout Rama-Jean
# Out:
# /content/ObraTrack
# Branch 'Rama-Jean' set up to track remote branch 'Rama-Jean' from 'origin'.
# Switched to a new branch 'Rama-Jean'

# %%
import os
os.environ['SUPABASE_URL'] = 'https://tu-proyecto.supabase.co'
os.environ['SUPABASE_KEY'] = 'sb_publishable_...(tu key completa)'
print('OK, credenciales definidas')

# %%
# !find / -iname "*obratrack-hu2*" 2>/dev/null

# %%
# !ls /content/temp_hu2
# Out:
# ls: cannot access '/content/temp_hu2': No such file or directory

# %%
# !git clone https://github.com/BySowy8/ObraTrack.git

# %cd ObraTrack


# !git checkout Rama-Cristhian
# Out:
# Cloning into 'ObraTrack'...
# remote: Enumerating objects: 39, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 39 (delta 14), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (39/39), 12.73 KiB | 766.00 KiB/s, done.
# Resolving deltas: 100% (14/14), done.
# /content/ObraTrack
# Branch 'Rama-Cristhian' set up to track remote branch 'Rama-Cristhian' from 'origin'.
# Switched to a new branch 'Rama-Cristhian'

# %%
from google.colab import drive; drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_2731/1187734714.py in <cell line: 0>()
# ----> 1 from google.colab import drive; drive.mount('/content/drive')
#
# /usr/local/lib/python3.13/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.13/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.13/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.13/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %%
# 1. Instalamos la librería oficial de Supabase
# !pip install supabase pandas

# 2. Importamos la librería
from supabase import create_client

# 3. Datos de conexión limpios
url = "https://syosgdsranzmrajczgrd.supabase.co"
key = "sb_publishable_P-zjN2qYgSN5Q6joPb36eA_AZR9W1Hw"

# 4. Inicializamos el cliente
supabase = create_client(url, key)

print(" Conexión a Supabase configurada exitosamente.")
# Out:
# Collecting supabase
#   Downloading supabase-2.31.0-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.13/dist-packages (2.2.3)
# Collecting realtime==2.31.0 (from supabase)
#   Downloading realtime-2.31.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting supabase-functions==2.31.0 (from supabase)
#   Downloading supabase_functions-2.31.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting storage3==2.31.0 (from supabase)
#   Downloading storage3-2.31.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting supabase-auth==2.31.0 (from supabase)
#   Downloading supabase_auth-2.31.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting postgrest==2.31.0 (from supabase)
#   Downloading postgrest-2.31.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: httpx<0.29,>=0.26 in /usr/local/lib/python3.13/dist-packages (from supabase) (0.28.1)
# Requirement already satisfied: yarl>=1.22.0 in /usr/local/lib/python3.13/dist-packages (from supabase) (1.24.5)
# Requirement already satisfied: deprecation>=2.1.0 in /usr/local/lib/python3.13/dist-packages (from postgrest==2.31.0->supabase) (2.1.0)
# Requirement already satisfied: pydantic<3.0,>=1.9 in /usr/local/lib/python3.13/dist-packages (from postgrest==2.31.0->supabase) (2.13.4)
# Requirement already satisfied: typing-extensions>=4.14.0 in /usr/local/lib/python3.13/dist-packages (from realtime==2.31.0->supabase) (4.16.0)
# Requirement already satisfied: websockets<16,>=11 in /usr/local/lib/python3.13/dist-packages (from realtime==2.31.0->supabase) (15.0.1)
# Requirement already satisfied: pyjwt>=2.12.0 in /usr/local/lib/python3.13/dist-packages (from pyjwt[crypto]>=2.12.0->supabase-auth==2.31.0->supabase) (2.13.0)
# Collecting strenum>=0.4.15 (from supabase-functions==2.31.0->supabase)
#   Downloading StrEnum-0.4.15-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.13/dist-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas) (2026.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx<0.29,>=0.26->supabase) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<0.29,>=0.26->supabase) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<0.29,>=0.26->supabase) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.13/dist-packages (from httpx<0.29,>=0.26->supabase) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<0.29,>=0.26->supabase) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: multidict>=4.0 in /usr/local/lib/python3.13/dist-packages (from yarl>=1.22.0->supabase) (6.7.1)
# Requirement already satisfied: propcache>=0.2.1 in /usr/local/lib/python3.13/dist-packages (from yarl>=1.22.0->supabase) (0.5.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from deprecation>=2.1.0->postgrest==2.31.0->supabase) (26.3)
# Requirement already satisfied: h2<5,>=3 in /usr/local/lib/python3.13/dist-packages (from httpx[http2]<0.29,>=0.26->postgrest==2.31.0->supabase) (4.4.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0,>=1.9->postgrest==2.31.0->supabase) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0,>=1.9->postgrest==2.31.0->supabase) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0,>=1.9->postgrest==2.31.0->supabase) (0.4.4)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.13/dist-packages (from pyjwt[crypto]>=2.12.0->supabase-auth==2.31.0->supabase) (50.0.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.12.0->supabase-auth==2.31.0->supabase) (2.1.1)
# Requirement already satisfied: hyperframe<7,>=6.1 in /usr/local/lib/python3.13/dist-packages (from h2<5,>=3->httpx[http2]<0.29,>=0.26->postgrest==2.31.0->supabase) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.2 in /usr/local/lib/python3.13/dist-packages (from h2<5,>=3->httpx[http2]<0.29,>=0.26->postgrest==2.31.0->supabase) (4.2.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.12.0->supabase-auth==2.31.0->supabase) (3.0)
# Downloading supabase-2.31.0-py3-none-any.whl (16 kB)
# Downloading postgrest-2.31.0-py3-none-any.whl (23 kB)
# Downloading realtime-2.31.0-py3-none-any.whl (22 kB)
# Downloading storage3-2.31.0-py3-none-any.whl (28 kB)
# Downloading supabase_auth-2.31.0-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 1.1 MB/s eta 0:00:00
# Downloading supabase_functions-2.31.0-py3-none-any.whl (8.8 kB)
# Downloading StrEnum-0.4.15-py3-none-any.whl (8.9 kB)
# Installing collected packages: strenum, realtime, supabase-functions, supabase-auth, storage3, postgrest, supabase
# Successfully installed postgrest-2.31.0 realtime-2.31.0 storage3-2.31.0 strenum-0.4.15 supabase-2.31.0 supabase-auth-2.31.0 supabase-functions-2.31.0
#  Conexión a Supabase configurada exitosamente.

# %%
# !mkdir -p /content/drive/MyDrive/ObraTrack_Sprint1

# %%
# %cd /content/drive/MyDrive/ObraTrack_Sprint1
# !git clone https://github.com/BySowy8/ObraTrack.git

# %%
# %cd ObraTrack
# !git checkout Rama-Jean

# %% [markdown]
# # (HU3) Consulta e historial de bitácora de obra

# %%
# %%writefile modulo_historial.py
import pandas as pd
from IPython.display import display, HTML

def obtener_datos_bitacora(supabase_client):
    """
    Obtiene todos los registros de la tabla 'bitacora' desde Supabase.
    """
    try:
        response = supabase_client.table("bitacora").select("*").execute()
        data = response.data
        if not data:
            return pd.DataFrame()
        return pd.DataFrame(data)
    except Exception as e:
        print(f"Error al obtener los datos: {e}")
        return pd.DataFrame()

def renderizar_historial_html(df):
    """
    Renderiza el historial con diseño minimalista y diferencia visual para imprevistos.
    """
    if df.empty:
        display(HTML("""
            <div style="font-family: -apple-system, sans-serif; padding: 15px; border: 1px solid #e1e4e8; background: #f6f8fa; color: #586069; font-size: 13px; max-width: 900px;">
                [Aviso] No hay registros en la bitácora todavía.
            </div>
        """))
        return

    # Estilos CSS limpios y adaptados para imprevistos
    estilos = """
    <style>
        .obratrack-container {
            font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, Helvetica, Arial, sans-serif;
            margin: 20px 0;
            max-width: 900px;
        }
        .obratrack-title {
            font-size: 15px;
            font-weight: 600;
            color: #24292e;
            margin-bottom: 8px;
            border-bottom: 1px solid #eaeaea;
            padding-bottom: 6px;
        }
        .obratrack-table {
            width: 100%;
            border-collapse: collapse;
            font-size: 13px;
            color: #24292e;
            background: #ffffff;
            border: 1px solid #e1e4e8;
        }
        .obratrack-table th {
            background-color: #f6f8fa;
            color: #24292e;
            font-weight: 600;
            text-align: left;
            padding: 8px 12px;
            border-bottom: 1px solid #e1e4e8;
        }
        .obratrack-table td {
            padding: 8px 12px;
            border-bottom: 1px solid #eaeaea;
            vertical-align: top;
        }
        .obratrack-table tr:hover {
            background-color: #f8f9fa;
        }
        /* Estilo sutil para filas con imprevistos */
        .fila-imprevisto {
            background-color: #fffdfd;
        }
        .badge-imprevisto {
            display: inline-block;
            padding: 2px 6px;
            font-size: 11px;
            font-weight: 500;
            color: #d73a49;
            background-color: #ffeef0;
            border: 1px solid rgba(27,31,35,0.15);
            border-radius: 3px;
            margin-top: 4px;
        }
        .badge-normal {
            color: #28a745;
            font-size: 12px;
        }
    </style>
    """

    # Construimos las filas de la tabla manualmente para inyectar la lógica de imprevistos
    filas_html = ""
    for _, row in df.iterrows():
        fecha = row.get('fecha', 'Sin fecha')
        avance = row.get('descripcion_avance', 'Sin descripción')
        imprevisto = row.get('imprevisto', None)

        if imprevisto and str(imprevisto).strip() and str(imprevisto).lower() != 'none':
            # Si hay imprevisto
            estado_html = f"<span class='badge-imprevisto'> IMPREVISTO: {imprevisto}</span>"
            clase_fila = "fila-imprevisto"
        else:
            estado_html = "<span class='badge-normal'>✓ Normal</span>"
            clase_fila = ""

        filas_html += f"""
        <tr class="{clase_fila}">
            <td style="white-space: nowrap; width: 110px;">{fecha}</td>
            <td>{avance}</td>
            <td style="width: 250px;">{estado_html}</td>
        </tr>
        """

    html_final = f"""
    {estilos}
    <div class="obratrack-container">
        <div class="obratrack-title">Historial de Avances (Bitácora)</div>
        <table class="obratrack-table">
            <thead>
                <tr>
                    <th>Fecha</th>
                    <th>Avance del Día</th>
                    <th>Estado / Observación</th>
                </tr>
            </thead>
            <tbody>
                {filas_html}
            </tbody>
        </table>
    </div>
    """

    display(HTML(html_final))
# Out:
# Overwriting modulo_historial.py

# %%
# Importamos desde tu propio módulo separado
import importlib
import modulo_historial
importlib.reload(modulo_historial)
from modulo_historial import obtener_datos_bitacora, renderizar_historial_html

# 1. Obtener datos
df_bitacora = obtener_datos_bitacora(supabase)

# 2. Renderizar interfaz
renderizar_historial_html(df_bitacora)
# Out:
#
#     <style>
#         .obratrack-container {
#             font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, Helvetica, Arial, sans-serif;
#             margin: 20px 0;
#             max-width: 900px;
#         }
#         .obratrack-title {
#             font-size: 15px;
#             font-weight: 600;
#             color: #24292e;
#             margin-bottom: 8px;
#             border-bottom: 1px solid #eaeaea;
#             padding-bottom: 6px;
#         }
#         .obratrack-table {
#             width: 100%;
#             border-collapse: collapse;
#             font-size: 13px;
#             color: #24292e;
#             background: #ffffff;
#             border: 1px solid #e1e4e8;
#         }
#         .obratrack-table th {
#             background-color: #f6f8fa;
#             color: #24292e;
#             font-weight: 600;
#             text-align: left;
#             padding: 8px 12px;
#             border-bottom: 1px solid #e1e4e8;
#         }
#         .obratrack-table td {
#             padding: 8px 12px;
#             border-bottom: 1px solid #eaeaea;
#             vertical-align: top;
#         }
#         .obratrack-table tr:hover {
#             background-color: #f8f9fa;
#         }
#         /* Estilo sutil para filas con imprevistos */
#         .fila-imprevisto {
#             background-color: #fffdfd;
#         }
#         .badge-imprevisto {
#             display: inline-block;
#             padding: 2px 6px;
#             font-size: 11px;
#             font-weight: 500;
#             color: #d73a49;
#             background-color: #ffeef0;
#             border: 1px solid rgba(27,31,35,0.15);
#             border-radius: 3px;
#             margin-top: 4px;
#         }
#         .badge-normal {
#             color: #28a745;
#             font-size: 12px;
#         }
#     </style>
#
#     <div class="obratrack-container">
#         <div class="obratrack-title">Historial de Avances (Bitácora)</div>
#         <table class="obratrack-table">
#             <thead>
#                 <tr>
#                     <th>Fecha</th>
#                     <th>Avance del Día</th>
#                     <th>Estado / Observación</th>
#                 </tr>
#             </thead>
#             <tbody>
#
#         <tr class="">
#             <td style="white-space: nowrap; width: 110px;">2026-08-20</td>
#             <td>Se realizó el vaciado de concreto en la zapata 3.</td>
#             <td style="width: 250px;"><span class='badge-normal'>✓ Normal</span></td>
#         </tr>
#
#         <tr class="fila-imprevisto">
#             <td style="white-space: nowrap; width: 110px;">2026-08-21</td>
#             <td>Colocación de tuberías de drenaje en el sector norte.</td>
#             <td style="width: 250px;"><span class='badge-imprevisto'> IMPREVISTO: Lluvia intensa detuvo el trabajo 2 horas.</span></td>
#         </tr>
#
#         <tr class="fila-imprevisto">
#             <td style="white-space: nowrap; width: 110px;">2026-08-21</td>
#             <td>Colocación de tuberías de drenaje en el sector norte.</td>
#             <td style="width: 250px;"><span class='badge-imprevisto'> IMPREVISTO: Lluvia intensa detuvo el trabajo 2 horas.</span></td>
#         </tr>
#
#         <tr class="">
#             <td style="white-space: nowrap; width: 110px;">2026-08-20</td>
#             <td>Vaciado de concreto en zapatas del sector A.</td>
#             <td style="width: 250px;"><span class='badge-normal'>✓ Normal</span></td>
#         </tr>
#
#         <tr class="fila-imprevisto">
#             <td style="white-space: nowrap; width: 110px;">2026-08-21</td>
#             <td>Instalación de tuberías subterráneas.</td>
#             <td style="width: 250px;"><span class='badge-imprevisto'> IMPREVISTO: Lluvia fuerte detuvo labores por 3 horas.</span></td>
#         </tr>
#
#         <tr class="fila-imprevisto">
#             <td style="white-space: nowrap; width: 110px;">2026-08-20</td>
#             <td>Se realizó el vaciado de concreto en la zapata 3.</td>
#             <td style="width: 250px;"><span class='badge-imprevisto'> IMPREVISTO: BOT</span></td>
#         </tr>
#
#         <tr class="">
#             <td style="white-space: nowrap; width: 110px;">2026-08-20</td>
#             <td>Se realizó el vaciado de concreto en la zapata 3.</td>
#             <td style="width: 250px;"><span class='badge-normal'>✓ Normal</span></td>
#         </tr>
#
#         <tr class="fila-imprevisto">
#             <td style="white-space: nowrap; width: 110px;">2026-08-21</td>
#             <td>Colocación de tuberías de drenaje en el sector norte.</td>
#             <td style="width: 250px;"><span class='badge-imprevisto'> IMPREVISTO: Lluvia intensa detuvo el trabajo 2 horas.</span></td>
#         </tr>
#
#             </tbody>
#         </table>
#     </div>

# %%
from datetime import date

class Bitacora:
    def __init__(self, supabase_client, tabla="Bitacora"):
        self.supabase = supabase_client
        self.tabla = tabla

    def registrar_avance(self, descripcion: str, fecha: str = None):
        """
        Registra un nuevo reporte diario de avance de obra.
        - descripcion: texto describiendo el avance del día
        - fecha: formato 'YYYY-MM-DD'. Si no se especifica, usa la fecha de hoy.
        """
        if fecha is None:
            fecha = date.today().isoformat()

        data = {
            "descripcion": descripcion,
            "fecha": fecha
        }

        response = self.supabase.table(self.tabla).insert(data).execute()
        print(f"✅ Bitácora registrada: {descripcion} ({fecha})")
        return response

    def obtener_bitacoras(self):
        """Devuelve todos los registros de bitácora, ordenados por fecha descendente."""
        response = self.supabase.table(self.tabla).select("*").order("fecha", desc=True).execute()
        return response.data

    def obtener_por_fecha(self, fecha: str):
        """Filtra los registros de bitácora por una fecha específica."""
        response = self.supabase.table(self.tabla).select("*").eq("fecha", fecha).execute()
        return response.data
