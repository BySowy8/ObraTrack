# %% [markdown]
# <a href="https://colab.research.google.com/github/BySowy8/ObraTrack/blob/main/ObraTrack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Holaa")
# Out:
# Holaa
